# %% [markdown]
# # Scoring Each Events for the Labels
#
#
# We aim to calculate a score for each event based on its $\texttt{AvgTone}$ value and its distance from a defined baseline route. The score will then be aggregated for events occurring on the same day. The process is as follows:
#
# ### Definitions
# $$
# \begin{align*}
# &\text{Let } (\mathbf{X}_0, \mathbf{Y}_0) \text{ represent the coordinates of the home.} \\
# &\text{Let } (\mathbf{X}_1, \mathbf{Y}_1) \text{ represent the coordinates of the work location.} \\
# &\text{Let } (\mathbf{x}_i, \mathbf{y}_i) \text{ be the coordinates of event } i \in E \text{ (the set of all events).} \\
# &\text{The line connecting home and work (baseline route) is parameterized as:} \\
# &\mathbf{r}(t) = (1 - t)(\mathbf{X}_0, \mathbf{Y}_0) + t(\mathbf{X}_1, \mathbf{Y}_1), \quad t \in [0,1].
# \end{align*}
# $$

# %% [markdown]
# ---
#
# Lets pull in the data and set the values.
#
# ---

# %%
# imports
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.colors as mcolors
import pandas as pd
import folium
import numpy as np
import matplotlib.pyplot as plt

# %%
target_data = pd.read_csv('csv/target_data.csv')
target_data.head()
# Out:
#          Date  EventCode                            ActionGeo_FullName  \
# 0  2024-08-23        145           Union Park, Illinois, United States
# 1  2024-08-22        145           Union Park, Illinois, United States
# 2  2024-08-20        145           Union Park, Illinois, United States
# 3  2024-08-20        145           Union Park, Illinois, United States
# 4  2024-06-27        145  Buckingham Fountain, Illinois, United States
#
#    ActionGeo_Lat  ActionGeo_Long   AvgTone
# 0        41.8839        -87.6648 -3.046968
# 1        41.8839        -87.6648  0.000000
# 2        41.8839        -87.6648 -4.319654
# 3        41.8839        -87.6648 -4.319654
# 4        41.8756        -87.6189 -7.052186

# %%
target_location = pd.read_csv('csv/target_location.csv')
target_location.head()
# Out:
#          lat        lon           event
# 0  41.911188 -87.675144            home
# 1  41.873000 -87.627650          school
# 2  41.865756 -87.684843  expanded_start
# 3  41.918433 -87.617952    expanded_end

# %%
X_0 = target_location.loc[target_location['event'] == 'home', 'lat'].values[0]
Y_0 = target_location.loc[target_location['event'] == 'home', 'lon'].values[0]
X_1 = target_location.loc[target_location['event'] == 'school', 'lat'].values[0]
Y_1 = target_location.loc[target_location['event'] == 'school', 'lon'].values[0]
X_0, Y_0, X_1, Y_1
# Out:
# (41.91118832433419, -87.67514378155508, 41.87300017458362, -87.62765043486581)

# %%
# Create a map centered around the midpoint of the baseline route
mid_lat = (X_0 + X_1) / 2
mid_lon = (Y_0 + Y_1) / 2
m = folium.Map(location=[mid_lat, mid_lon], zoom_start=13)

# Add markers for the start and end points
folium.Marker([X_0, Y_0], popup='Home', icon=folium.Icon(color='green')).add_to(m)
folium.Marker([X_1, Y_1], popup='Work', icon=folium.Icon(color='red')).add_to(m)

# Add a line for the baseline route
folium.PolyLine(locations=[[X_0, Y_0], [X_1, Y_1]], color='blue').add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_95a42cbe059afec88caa76a1390c482c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_95a42cbe059afec88caa76a1390c482c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_95a42cbe059afec88caa76a1390c482c = L.map(
#                 &quot;map_95a42cbe059afec88caa76a1390c482c&quot;,
#                 {
#                     center: [41.89209424945891, -87.65139710821045],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8c34ac9c0c26a4b40c2e530233267911 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8c34ac9c0c26a4b40c2e530233267911.addTo(map_95a42cbe059afec88caa76a1390c482c);
#
#
#             var marker_7fb658a03be4e2881486a74ae980ade1 = L.marker(
#                 [41.91118832433419, -87.67514378155508],
#                 {
# }
#             ).addTo(map_95a42cbe059afec88caa76a1390c482c);
#
#
#             var icon_adc9795b1f330f5f040b83b199d26bb6 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_7fb658a03be4e2881486a74ae980ade1.setIcon(icon_adc9795b1f330f5f040b83b199d26bb6);
#
#
#         var popup_2a6378611b05210ae5299b7620d617e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aeb033f7bfe1969e23957027f26518ab = $(`&lt;div id=&quot;html_aeb033f7bfe1969e23957027f26518ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Home&lt;/div&gt;`)[0];
#                 popup_2a6378611b05210ae5299b7620d617e6.setContent(html_aeb033f7bfe1969e23957027f26518ab);
#
#
#
#         marker_7fb658a03be4e2881486a74ae980ade1.bindPopup(popup_2a6378611b05210ae5299b7620d617e6)
#         ;
#
#
#
#
#             var marker_61541e90abd1469ef05791d4a1ca4968 = L.marker(
#                 [41.87300017458362, -87.62765043486581],
#                 {
# }
#             ).addTo(map_95a42cbe059afec88caa76a1390c482c);
#
#
#             var icon_67f4939f570ee052f61a0bc33e53357e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_61541e90abd1469ef05791d4a1ca4968.setIcon(icon_67f4939f570ee052f61a0bc33e53357e);
#
#
#         var popup_fb2beaf25ef317a1caa52300e40b9f18 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0d820bdf97e56a15c2d0c3bf3dfc8d5 = $(`&lt;div id=&quot;html_f0d820bdf97e56a15c2d0c3bf3dfc8d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Work&lt;/div&gt;`)[0];
#                 popup_fb2beaf25ef317a1caa52300e40b9f18.setContent(html_f0d820bdf97e56a15c2d0c3bf3dfc8d5);
#
#
#
#         marker_61541e90abd1469ef05791d4a1ca4968.bindPopup(popup_fb2beaf25ef317a1caa52300e40b9f18)
#         ;
#
#
#
#
#             var poly_line_942b18b6f3dc20978abacb32ee85ef1c = L.polyline(
#                 [[41.91118832433419, -87.67514378155508], [41.87300017458362, -87.62765043486581]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_95a42cbe059afec88caa76a1390c482c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Distance Calculation
# The perpendicular distance $d_i$ from event $i$ to the baseline route is computed as:
# $$
# \begin{align*}
# d_i = \frac{|(\mathbf{X}_1 - \mathbf{X}_0)(\mathbf{Y}_0 - \mathbf{y}_i) - (\mathbf{Y}_1 - \mathbf{Y}_0)(\mathbf{X}_0 - \mathbf{x}_i)|}{\sqrt{(\mathbf{X}_1 - \mathbf{X}_0)^2 + (\mathbf{Y}_1 - \mathbf{Y}_0)^2}}.
# \end{align*}
# $$

# %%
# Calculate the perpendicular distance d_i for each event
target_data['d_i'] = target_data.apply(
    lambda row: abs((X_1 - X_0) * (Y_0 - row['ActionGeo_Long']) - (Y_1 - Y_0) * (X_0 - row['ActionGeo_Lat'])) / np.sqrt((X_1 - X_0)**2 + (Y_1 - Y_0)**2),
    axis=1
)

target_data.head()
# Out:
#          Date  EventCode                            ActionGeo_FullName  \
# 0  2024-08-23        145           Union Park, Illinois, United States
# 1  2024-08-22        145           Union Park, Illinois, United States
# 2  2024-08-20        145           Union Park, Illinois, United States
# 3  2024-08-20        145           Union Park, Illinois, United States
# 4  2024-06-27        145  Buckingham Fountain, Illinois, United States
#
#    ActionGeo_Lat  ActionGeo_Long   AvgTone       d_i
# 0        41.8839        -87.6648 -3.046968  0.014785
# 1        41.8839        -87.6648  0.000000  0.014785
# 2        41.8839        -87.6648 -4.319654  0.014785
# 3        41.8839        -87.6648 -4.319654  0.014785
# 4        41.8756        -87.6189 -7.052186  0.007509

# %% [markdown]
# ### Event Scoring
#
# Each event $i$ is assigned a score based on its \texttt{AvgTone} value and its distance $d_i$:
# $$
# \begin{align*}
# \text{Score}_i = \frac{\text{AvgTone}_i}{d_i}.
# \end{align*}
# $$

# %%
target_data['Score'] = target_data['AvgTone'] / target_data['d_i']
target_data.head()
# Out:
#          Date  EventCode                            ActionGeo_FullName  \
# 0  2024-08-23        145           Union Park, Illinois, United States
# 1  2024-08-22        145           Union Park, Illinois, United States
# 2  2024-08-20        145           Union Park, Illinois, United States
# 3  2024-08-20        145           Union Park, Illinois, United States
# 4  2024-06-27        145  Buckingham Fountain, Illinois, United States
#
#    ActionGeo_Lat  ActionGeo_Long   AvgTone       d_i       Score
# 0        41.8839        -87.6648 -3.046968  0.014785 -206.091176
# 1        41.8839        -87.6648  0.000000  0.014785    0.000000
# 2        41.8839        -87.6648 -4.319654  0.014785 -292.173275
# 3        41.8839        -87.6648 -4.319654  0.014785 -292.173275
# 4        41.8756        -87.6189 -7.052186  0.007509 -939.118761

# %%
# Create a map centered around the midpoint of the baseline route
m_events = folium.Map(location=[mid_lat, mid_lon], zoom_start=13)

# Normalize distances and scores for color mapping
norm_distance = mcolors.Normalize(vmin=target_data['d_i'].min(), vmax=target_data['d_i'].max())
norm_score = mcolors.Normalize(vmin=target_data['Score'].min(), vmax=target_data['Score'].max())
cmap = LinearSegmentedColormap.from_list('red_white', ['red', 'white'])

# Add markers for each event with a popup showing the score
for _, row in target_data.iterrows():
    color = mcolors.to_hex(cmap(norm_score(row['Score'])))
    radius = 15 - 10 * norm_distance(row['d_i'])  # Scale radius between 5 and 15, inverted
    folium.CircleMarker(
        location=[row['ActionGeo_Lat'], row['ActionGeo_Long']],
        radius=radius,
        popup=f"Distance: {row['d_i']:.2f}, Score: {row['Score']:.2f}",
        color='black',  # Fixed outline color
        fill=True,
        fill_color=color
    ).add_to(m_events)

# Add a line for the baseline route
folium.PolyLine(locations=[[X_0, Y_0], [X_1, Y_1]], color='blue').add_to(m_events)

# Display the map
m_events
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7b99e4ef755e53509c66af075236a2ff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7b99e4ef755e53509c66af075236a2ff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7b99e4ef755e53509c66af075236a2ff = L.map(
#                 &quot;map_7b99e4ef755e53509c66af075236a2ff&quot;,
#                 {
#                     center: [41.89209424945891, -87.65139710821045],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ea2aaf4b4390b3bbf9812a05b3bbe436 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ea2aaf4b4390b3bbf9812a05b3bbe436.addTo(map_7b99e4ef755e53509c66af075236a2ff);
#
#
#             var circle_marker_53227c1228c4b8bd4db981a38bd90f0e = L.circleMarker(
#                 [41.8839, -87.6648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffdede&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9.211987529656529, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7b99e4ef755e53509c66af075236a2ff);
#
#
#         var popup_d727e04a6b7ee1c4aa173793f7012a2d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64c1b5d0e92d36c8ea8a26374435e413 = $(`&lt;div id=&quot;html_64c1b5d0e92d36c8ea8a26374435e413&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Distance: 0.01, Score: -206.09&lt;/div&gt;`)[0];
#                 popup_d727e04a6b7ee1c4aa173793f7012a2d.setContent(html_64c1b5d0e92d36c8ea8a26374435e413);
#
#
#
#         circle_marker_53227c1228c4b8bd4db981a38bd90f0e.bindPopup(popup_d727e04a6b7ee1c4aa173793f7012a2d)
#         ;
#
#
#
#
#             var circle_marker_3ec8bb380b1a01fb2a8b4d7b85f295ef = L.circleMarker(
#                 [41.8839, -87.6648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fff1f1&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9.211987529656529, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7b99e4ef755e53509c66af075236a2ff);
#
#
#         var popup_5c6ffac51d67997600f1c54b4271eb7f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_582048a062f055cff7f7a26934920df0 = $(`&lt;div id=&quot;html_582048a062f055cff7f7a26934920df0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Distance: 0.01, Score: 0.00&lt;/div&gt;`)[0];
#                 popup_5c6ffac51d67997600f1c54b4271eb7f.setContent(html_582048a062f055cff7f7a26934920df0);
#
#
#
#         circle_marker_3ec8bb380b1a01fb2a8b4d7b85f295ef.bindPopup(popup_5c6ffac51d67997600f1c54b4271eb7f)
#         ;
#
#
#
#
#             var circle_marker_be59d48ce10542a53074491308a0e492 = L.circleMarker(
#                 [41.8839, -87.6648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffd6d6&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9.211987529656529, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7b99e4ef755e53509c66af075236a2ff);
#
#
#         var popup_fe4b6167305517a19b14114f6259ec16 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e99fc38d1615a733fde79a35df930c8 = $(`&lt;div id=&quot;html_7e99fc38d1615a733fde79a35df930c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Distance: 0.01, Score: -292.17&lt;/div&gt;`)[0];
#                 popup_fe4b6167305517a19b14114f6259ec16.setContent(html_7e99fc38d1615a733fde79a35df930c8);
#
#
#
#         circle_marker_be59d48ce10542a53074491308a0e492.bindPopup(popup_fe4b6167305517a19b14114f6259ec16)
#         ;
#
#
#
#
#             var circle_marker_c107d5606b5a457c55f7a1644a556cd9 = L.circleMarker(
#                 [41.8839, -87.6648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &qu

# %% [markdown]
# ---
#
# This looks accurate. The colors represent the score, and the radii represent the distance. Radii is clearly correct, and it's clear color is also darker towards the line.
#
# ---

# %% [markdown]
# ### Daily Aggregated Score
# For all events $j$ occurring on the same day as event $i$, the daily aggregated score is computed as:
# $$
# \begin{align*}
# \text{Daily Score}_{\text{day}} = \sum_{j \in \text{same day}} \frac{\text{AvgTone}_j}{d_j}.
# \end{align*}
# $$

# %%
# Convert Date to datetime
target_data['Date'] = pd.to_datetime(target_data['Date'], format='%Y-%m-%d')

# Aggregate target_data by date and calculate the total score for each day
aggregated = target_data.groupby('Date').agg({'Score': 'sum'}).reset_index()
aggregated.columns = ['Date', 'Total Score']

# Create a date range and reindex the dataframe
all_dates = pd.date_range(start=aggregated['Date'].min(), end=pd.Timestamp.today())
daily_score = aggregated.set_index('Date').reindex(all_dates, fill_value=0).reset_index()

# Rename columns
daily_score.columns = ['Date', 'Total Score']

# Display the resulting DataFrame
daily_score
# Out:
#            Date  Total Score
# 0    2015-12-25  -589.428382
# 1    2015-12-26     0.000000
# 2    2015-12-27     0.000000
# 3    2015-12-28     0.000000
# 4    2015-12-29     0.000000
# ...         ...          ...
# 3287 2024-12-24     0.000000
# 3288 2024-12-25     0.000000
# 3289 2024-12-26     0.000000
# 3290 2024-12-27     0.000000
# 3291 2024-12-28     0.000000
#
# [3292 rows x 2 columns]

# %%
# Plot the Total Score over time
plt.figure(figsize=(12, 6))
plt.plot(daily_score['Date'], daily_score['Total Score'], linestyle='-')
plt.title('Total Score Over Time')
plt.xlabel('Date')
plt.ylabel('Total Score')
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# Still don't really understand the positive scores here...
#
# ---

# %%
plt.figure(figsize=(12, 6))
plt.hist(daily_score['Total Score'], bins=30, edgecolor='black', log=True)
plt.title('Histogram of Total Score')
plt.xlabel('Total Score')
plt.ylabel('Frequency (log scale)')
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# Log y for visibility.
#
# ---

# %% [markdown]
# ---
#
# Save labels.
#
# ---

# %%
daily_score.to_csv('model_csv/daily_score.csv', index=False)
