# %% [markdown]
# # Starting From Scratch to Keep Things Simple

# %%
from geopy.distance import geodesic, distance
from geopy import Point

# Original coordinates
home_lat, home_lon = 41.91118832433419, -87.67514378155508
school_lat, school_lon = 41.87300017458362, -87.62765043486581

min_lat = min(home_lat, school_lat)
max_lat = max(home_lat, school_lat)

min_lon = min(home_lon, school_lon)
max_lon = max(home_lon, school_lon)
# Add 3 miles to max_lat and max_lon, subtract 3 miles from min_lat and min_lon
max_lat += distance(miles=3).destination(Point(max_lat, max_lon), 0).latitude - max_lat
max_lon += distance(miles=3).destination(Point(max_lat, max_lon), 90).longitude - max_lon

min_lat -= min_lat - distance(miles=3).destination(Point(min_lat, min_lon), 180).latitude
min_lon -= min_lon - distance(miles=3).destination(Point(min_lat, min_lon), 270).longitude

# %%
import folium

# Create a map centered around the initial home coordinates
m = folium.Map(location=[home_lat, home_lon], zoom_start=13)

# Add markers for the initial home and school coordinates
folium.Marker([home_lat, home_lon], popup='Home', icon=folium.Icon(color='blue')).add_to(m)
folium.Marker([school_lat, school_lon], popup='School', icon=folium.Icon(color='red')).add_to(m)
# Add a rectangle to represent the bounding box
folium.Rectangle(
    bounds=[[min_lat, min_lon], [max_lat, max_lon]],
    color='green',
    fill=True,
    fill_opacity=0.2
).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_058bbf26b3460a960814144d99693464 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_058bbf26b3460a960814144d99693464&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_058bbf26b3460a960814144d99693464 = L.map(
#                 &quot;map_058bbf26b3460a960814144d99693464&quot;,
#                 {
#                     center: [41.91118832433419, -87.67514378155508],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_529526673c700058ee456eac51f860ba = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_529526673c700058ee456eac51f860ba.addTo(map_058bbf26b3460a960814144d99693464);
#
#
#             var marker_e00198be6e977ee83f3288289f243988 = L.marker(
#                 [41.91118832433419, -87.67514378155508],
#                 {
# }
#             ).addTo(map_058bbf26b3460a960814144d99693464);
#
#
#             var icon_73d256f6a222a6560f0dca9b9c1a4812 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_e00198be6e977ee83f3288289f243988.setIcon(icon_73d256f6a222a6560f0dca9b9c1a4812);
#
#
#         var popup_f22631abea3245c8ea419de7b2943a99 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d23425b370f015a848f4af1b62105968 = $(`&lt;div id=&quot;html_d23425b370f015a848f4af1b62105968&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Home&lt;/div&gt;`)[0];
#                 popup_f22631abea3245c8ea419de7b2943a99.setContent(html_d23425b370f015a848f4af1b62105968);
#
#
#
#         marker_e00198be6e977ee83f3288289f243988.bindPopup(popup_f22631abea3245c8ea419de7b2943a99)
#         ;
#
#
#
#
#             var marker_5df19f7ba1d7cd952a51422cac26c6a7 = L.marker(
#                 [41.87300017458362, -87.62765043486581],
#                 {
# }
#             ).addTo(map_058bbf26b3460a960814144d99693464);
#
#
#             var icon_2a1d4291e427250716639e8652cf411f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_5df19f7ba1d7cd952a51422cac26c6a7.setIcon(icon_2a1d4291e427250716639e8652cf411f);
#
#
#         var popup_f71ffc2c5c3235a8089015c684693190 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_51eed774231a9567e87e0a24876f90f6 = $(`&lt;div id=&quot;html_51eed774231a9567e87e0a24876f90f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;School&lt;/div&gt;`)[0];
#                 popup_f71ffc2c5c3235a8089015c684693190.setContent(html_51eed774231a9567e87e0a24876f90f6);
#
#
#
#         marker_5df19f7ba1d7cd952a51422cac26c6a7.bindPopup(popup_f71ffc2c5c3235a8089015c684693190)
#         ;
#
#
#
#
#             var rectangle_3abe274b53e20fba9fffca1f73e33a51 = L.rectangle(
#                 [[41.829531958393524, -87.73326275316111], [41.954655920264784, -87.56941792740936]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_058bbf26b3460a960814144d99693464);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Log in to Google Cloud
#!gcloud auth application-default login

# %%
from google.cloud import bigquery

# Initialize BigQuery client with the project ID
client = bigquery.Client(project="civil-unrest-predictor")

query = f"""
SELECT
    GlobalEventID,
    SQLDATE,
    DATEADDED,
    IsRootEvent,
    EventCode,
    EventBaseCode,
    EventRootCode,
    GoldsteinScale,
    NumMentions,
    AvgTone,
    ActionGeo_FullName,
    ActionGeo_Lat,
    ActionGeo_Long
FROM
    `gdelt-bq.full.events`
WHERE
    EventCode IN ('145', '1451', '1452', '1453', '1454', '024', '0241', '0242', '0243', '0244', '0252', '0253', 
                  '090', '091', '092', '093', '094', '104', '1041', '1042', '1043', '1044', '1052', '1053', 
                  '111', '113', '114', '1232', '1233', '1234', '1242', '1243', '133', '1383', '139', 
                  '141', '1411', '1412', '1413', '1414', '144', '143', '1723', '1724', '175', 
                  '182', '183', '184')
    AND ActionGeo_Lat BETWEEN {min_lat} AND {max_lat}
    AND ActionGeo_Long BETWEEN {min_lon} AND {max_lon}
ORDER BY
    SQLDATE DESC
LIMIT 1000000;
"""

# Execute the updated query
query_job = client.query(query)

# Convert results to a DataFrame
data = query_job.result().to_dataframe()

# %%
display(data.head())
# Out:
#    GlobalEventID   SQLDATE  DATEADDED  IsRootEvent EventCode EventBaseCode  \
# 0     1218008600  20241229   20241229            1       111           111
# 1     1218059434  20241229   20241229            1       090           090
# 2     1217968727  20241229   20241229            1       111           111
# 3     1218064446  20241229   20241229            1       090           090
# 4     1218009043  20241229   20241229            1       111           111
#
#   EventRootCode  GoldsteinScale  NumMentions   AvgTone  \
# 0            11            -2.0            3  6.336634
# 1            09            -2.0           10 -6.250000
# 2            11            -2.0            4  0.806952
# 3            09            -2.0           10  0.884956
# 4            11            -2.0            3  6.336634
#
#                  ActionGeo_FullName  ActionGeo_Lat  ActionGeo_Long
# 0  Chicago, Illinois, United States          41.85        -87.6501
# 1  Chicago, Illinois, United States          41.85        -87.6501
# 2  Chicago, Illinois, United States          41.85        -87.6501
# 3  Chicago, Illinois, United States          41.85        -87.6501
# 4  Chicago, Illinois, United States          41.85        -87.6501

# %%
from datetime import datetime
import pandas as pd

# Convert SQLDATE to datetime format
data['SQLDATE'] = pd.to_datetime(data['SQLDATE'], format='%Y%m%d')

# Rename the 'SQLDATE' column to 'Date'
data.rename(columns={'SQLDATE': 'Date'}, inplace=True)

# %%
# Convert DATEADDED to datetime format
data['DATEADDED'] = pd.to_datetime(data['DATEADDED'], format='%Y%m%d')

# %%
display(data)
# Out:
#         GlobalEventID       Date  DATEADDED  IsRootEvent EventCode  \
# 0          1218008600 2024-12-29 2024-12-29            1       111
# 1          1218059434 2024-12-29 2024-12-29            1       090
# 2          1217968727 2024-12-29 2024-12-29            1       111
# 3          1218064446 2024-12-29 2024-12-29            1       090
# 4          1218009043 2024-12-29 2024-12-29            1       111
# ...               ...        ...        ...          ...       ...
# 211382      896123210 1920-01-01 2020-01-01            1       114
# 211383      896167951 1920-01-01 2020-01-01            1       182
# 211384      896076819 1920-01-01 2020-01-01            1       182
# 211385      896076841 1920-01-01 2020-01-01            1       182
# 211386      896104319 1920-01-01 2020-01-01            1       175
#
#        EventBaseCode EventRootCode  GoldsteinScale  NumMentions   AvgTone  \
# 0                111            11            -2.0            3  6.336634
# 1                090            09            -2.0           10 -6.250000
# 2                111            11            -2.0            4  0.806952
# 3                090            09            -2.0           10  0.884956
# 4                111            11            -2.0            3  6.336634
# ...              ...           ...             ...          ...       ...
# 211382           114            11            -2.0            2 -5.252918
# 211383           182            18            -9.5            5 -6.410256
# 211384           182            18            -9.5            4 -7.142857
# 211385           182            18            -9.5            3 -7.142857
# 211386           175            17            -9.0            1 -4.509091
#
#                                  ActionGeo_FullName  ActionGeo_Lat  \
# 0                  Chicago, Illinois, United States        41.8500
# 1                  Chicago, Illinois, United States        41.8500
# 2                  Chicago, Illinois, United States        41.8500
# 3                  Chicago, Illinois, United States        41.8500
# 4                  Chicago, Illinois, United States        41.8500
# ...                                             ...            ...
# 211382             Chicago, Illinois, United States        41.8500
# 211383             Chicago, Illinois, United States        41.8500
# 211384  East Garfield Park, Illinois, United States        41.8809
# 211385  East Garfield Park, Illinois, United States        41.8809
# 211386             Chicago, Illinois, United States        41.8500
#
#         ActionGeo_Long
# 0             -87.6501
# 1             -87.6501
# 2             -87.6501
# 3             -87.6501
# 4             -87.6501
# ...                ...
# 211382        -87.6501
# 211383        -87.6501
# 211384        -87.7028
# 211385        -87.7028
# 211386        -87.6501
#
# [211387 rows x 13 columns]

# %%
data.to_csv('csv/data.csv', index=False)
